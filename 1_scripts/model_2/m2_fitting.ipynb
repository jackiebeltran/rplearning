# %% [markdown]
# ### Objective: this notebook serves to fit HC behavioral data to model 2 (2 LR)

# %%
import numpy as np  

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import glob
import math
import os

from scipy.stats import norm
from scipy.optimize import minimize

import import_ipynb

# %%
os.getcwd()
# Out:
# '/Users/jackiebeltran/Documents/GitHub/RP_Learning/1_scripts/model_2'

# %% [markdown]
# #### load recoded data

# %%
flist = glob.glob('../../0_data/healthy/*.csv')
print('HC participants in this dataset are: ' + str(len(flist)))
# Out:
# HC participants in this dataset are: 38

# %%
mlist = glob.glob('../../0_data/mdd/*.csv')
print('MDD participants in this dataset are: ' + str(len(flist)))
# Out:
# MDD participants in this dataset are: 38

# %% [markdown]
# ###### All subjects

# %%
flist = glob.glob('../../0_data/N_76/*.csv')
print('participants in this dataset are: ' + str(len(flist)))
# Out:
# participants in this dataset are: 76

# %% [markdown]
# #### define functions

# %%
def m2_loglikelihood(training_params, actions, rewards, condition):

    r_alpha = training_params[0]
    p_alpha = training_params[1]
    beta = training_params[2]

    q_value = np.ones((3,2))*0.0
    T = len(actions)
    L = 0  
    
    for t in range(T):
        
        # compute choice probabilities of picking an action based on soft max 
        p = np.exp(beta * q_value[condition[t]-1,:]) / (np.exp(beta * q_value[condition[t]-1,:])).sum()

        # compute choice probability for actual choice based on the probability computed above by condition 
        choiceProb = p[actions[t]-1]

        # sum of the natural log of each individual choice probability to get the prob of a whole dataset (90 trials)
        L += np.log(choiceProb) 
    
        # update values with q learning, index for t and update by condition using the two separate learning rates
        if condition[t] == 1:
            q_value[condition[t]-1, actions[t]-1] = q_value[condition[t]-1, actions[t]-1] + r_alpha * (rewards[t] - q_value[condition[t]-1, actions[t]-1])
        elif condition[t] == 2:
            q_value[condition[t]-1, actions[t]-1] = q_value[condition[t]-1, actions[t]-1] + p_alpha * (rewards[t] - q_value[condition[t]-1, actions[t]-1])
    
    return -L

# %%
def fit_RP_Learning(actions, rewards, condition):

    init_cond = np.array([np.random.uniform(0,1), # reward alpha
                          np.random.uniform(0,1), # punishment alpha
                         np.random.randint(1,50)]) # beta 
    
    bnds = [(1e-6,1), (1e-6,1), (1,50)]
    
    optimum_output = minimize(m2_loglikelihood, init_cond, args=(actions, rewards, condition), method='L-BFGS-B', bounds=bnds)
     
    return optimum_output, init_cond

# %%
def model2_BIC(actions, rewards, condition):
    
    init_cond = np.array([np.random.uniform(0,1), # reward alpha
                          np.random.uniform(0,1), # punishment alpha
                         np.random.randint(1,50)]) # beta 
     
    bnds = [(1e-6,1), (1e-6,1), (1,50)]
    km = len(bnds) # number of parameters fit in the model
    
    optimum_output = minimize(m2_loglikelihood, init_cond, args=(actions, rewards, condition), method='L-BFGS-B', bounds=bnds)
    
    neg_loglikelihood = optimum_output.fun
    
    BIC = km * np.log(len(actions)) + 2*neg_loglikelihood 
    
    return BIC

# %%
def fitting(filename):    
    
    parameters = [] # empty list to store results

    a = os.path.basename(filename)
    subID = os.path.splitext(a)[0]

    # load data & subset for columns of interest
    df = pd.read_csv(filename)

    col_name = ['sub_ID', 'actions','rewards', 'condition']   
    sub_df = df[col_name]

    # Obtain parameters (actions, rewards, conditions)  
    actions = sub_df['actions']
    reward = sub_df['rewards']
    condition = sub_df["condition"]

    # compute best fit parameters which comes from fitting function
    res, init_cond = fit_RP_Learning(actions, reward, condition) # optimizer

    initial_values = init_cond
    
    # save fitted parameters as an array 
    fit_params = np.array([res.x[0], res.x[1], res.x[2]])
    
    max_LL = m2_loglikelihood(fit_params, actions, reward, condition) 

    LL_per_trial = np.exp(-max_LL/len(actions))

    ## Model recovery             
    BIC_model2 = model2_BIC(actions, reward, condition) 

    results_df = pd.DataFrame({
    'subject_ID': subID,  
    'initial_reward_conditions': initial_values[0],
    'initial_punishment_conditions': initial_values[1],
    'initial_beta_conditions' : initial_values[2],
    'fit_reward_alpha': res.x[0],
    'fit_punishment_alpha': res.x[1],
    'fit_beta' : res.x[2],
    'log_likelihood': -max_LL,
    'BIC_model2': BIC_model2,
    'likelihood_per_trial': LL_per_trial}, 
    index=pd.Index(sub_df['sub_ID'].unique(), name='participant_id'))
        
    parameters.append(results_df)


    final_result_df = pd.concat(parameters, ignore_index=True)
    
    return final_result_df

# %% [markdown]
# #### fit the data

# %%
n_iter = 5
final_df = pd.DataFrame()

for j in np.arange(n_iter) + 1:
    
    for i in mlist: # FOR MDD
    #  for i in flist: # FOR ALL SUBJECTS
        iteration_results = fitting(i)
        
        # add iteration column 
        iteration_results['Iteration'] = j
                
        final_df = final_df.append(iteration_results, ignore_index=True)
        final_df = final_df.sort_values(by=["subject_ID", "Iteration"])

final_df
# Out:
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
# /var/folders/jc/p5x3b5x57nj1x3fy75x85xwr0000gn/T/ipykernel_16952/2124389525.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(iteration_results, ignore_index=True)
#     subject_ID  initial_reward_conditions  initial_punishment_conditions  \
# 0          401                   0.761929                       0.992035
# 1          401                   0.261853                       0.387359
# 2          401                   0.406398                       0.443551
# 3          401                   0.143224                       0.857785
# 4          401                   0.215471                       0.015683
# ..         ...                        ...                            ...
# 184        455                   0.106702                       0.832925
# 185        455                   0.091267                       0.092768
# 186        455                   0.026543                       0.360004
# 187        455                   0.081345                       0.015270
# 188        455                   0.815334                       0.126834
#
#      initial_beta_conditions  fit_reward_alpha  fit_punishment_alpha  \
# 0                       33.0          0.400564              0.132609
# 1                        4.0          0.400567              0.132605
# 2                       23.0          0.400564              0.132604
# 3                       17.0          0.400565              0.132604
# 4                       27.0          0.400556              0.132605
# ..                       ...               ...                   ...
# 184                      5.0          0.693353              0.064746
# 185                     25.0          0.008426              0.012253
# 186                     30.0          0.008426              0.012253
# 187                     15.0          0.032667              0.035516
# 188                     39.0          0.965531              0.012253
#
#       fit_beta  log_likelihood  BIC_model2  likelihood_per_trial  Iteration
# 0     8.455133      -37.290661   88.080751              0.660776          1
# 1     8.455384      -37.290661   88.080751              0.660776          2
# 2     8.455447      -37.290661   88.080751              0.660776          3
# 3     8.455401      -37.290661   88.080751              0.660776          4
# 4     8.455285      -37.290661   89.341134              0.660776          5
# ..         ...             ...         ...                   ...        ...
# 184   7.692783      -43.016337   99.532102              0.620047          1
# 185  50.000000      -44.459437   99.532102              0.610185          2
# 186  50.000000      -44.459437   99.532102              0.610185          3
# 187  14.993451      -44.586647  102.418303              0.609323          4
# 188  50.000000      -43.017159   99.532102              0.620042          5
#
# [190 rows x 11 columns]

# %%
## FOR HEALTHY CONTROLS

final_df.to_csv('../../3_results/model_2/HC_fitting_results.csv')

# %%
## FOR MDD 

final_df.to_csv('../../3_results/model_2/MDD_fitting_results.csv')

# %%
### All subjects 
final_df.to_csv('../../3_results/model_2/N76_fitting_results.csv')

# %% [markdown]
# #### keep greatest likelihood

# %%
df_sorted = final_df.sort_values(['subject_ID', 'likelihood_per_trial'], ascending=[True, False])
df_highest_likelihood = df_sorted.groupby('subject_ID').first().reset_index()
df_highest_likelihood
# Out:
#    subject_ID  initial_reward_conditions  initial_punishment_conditions  \
# 0         401                   0.261853                       0.387359
# 1         402                   0.296034                       0.735612
# 2         408                   0.888023                       0.763353
# 3         409                   0.968474                       0.444753
# 4         410                   0.587989                       0.226288
# 5         413                   0.941062                       0.416180
# 6         415                   0.207327                       0.734232
# 7         416                   0.934953                       0.148102
# 8         417                   0.147810                       0.781793
# 9         418                   0.699189                       0.107451
# 10        419                   0.322609                       0.021211
# 11        420                   0.893844                       0.386091
# 12        421                   0.826945                       0.411752
# 13        422                   0.623008                       0.692911
# 14        423                   0.008567                       0.899521
# 15        424                   0.934494                       0.940489
# 16        425                   0.490649                       0.780329
# 17        427                   0.703320                       0.625640
# 18        428                   0.321568                       0.732123
# 19        430                   0.991058                       0.237573
# 20        431                   0.809360                       0.672751
# 21        432                   0.740746                       0.997222
# 22        434                   0.427115                       0.380007
# 23        435                   0.143551                       0.764621
# 24        436                   0.402914                       0.345580
# 25        438                   0.523098                       0.533157
# 26        440                   0.599652                       0.998968
# 27        442                   0.517541                       0.993123
# 28        443                   0.549732                       0.568754
# 29        444                   0.486443                       0.773738
# 30        445                   0.798417                       0.923319
# 31        446                   0.830323                       0.691798
# 32        447                   0.357633                       0.192418
# 33        450                   0.366570                       0.085992
# 34        451                   0.925368                       0.173611
# 35        453                   0.356733                       0.506421
# 36        454                   0.248743                       0.664584
# 37        455                   0.106702                       0.832925
#
#     initial_beta_conditions  fit_reward_alpha  fit_punishment_alpha  \
# 0                       4.0          0.400567              0.132605
# 1                      12.0          0.477326              0.173945
# 2                       6.0          0.000001              0.000001
# 3                      10.0          0.011287              0.004338
# 4                      36.0          0.002828              0.019379
# 5                       1.0          0.372604              0.078903
# 6                      33.0          0.904114              0.021822
# 7                      20.0          0.043978              0.537191
# 8                      42.0          0.046942              0.848762
# 9                      15.0          0.376755              0.030578
# 10                     48.0          0.735503              0.175995
# 11                     18.0          0.408333              0.000001
# 12                     31.0          0.969106              0.048972
# 13                      2.0          0.376665              0.848439
# 14                     23.0          0.967679              0.008766
# 15                     18.0          0.542671              0.054007
# 16                      3.0          0.003571              0.000562
# 17                      2.0          1.000000              0.039919
# 18                     30.0          1.000000              0.004410
# 19                     19.0          0.279272              0.491866
# 20                     23.0          0.293116              0.259590
# 21                     20.0          0.021139              0.000001
# 22                     25.0          0.005222              0.003281
# 23                      2.0          0.000001              0.052285
# 24                      4.0          0.000001              0.000001
# 25                     20.0          0.000001              0.000001
# 26                      8.0          0.498410              0.003670
# 27                      1.0          0.227814              0.025850
# 28                     46.0          0.003438              0.003312
# 29                      1.0          0.715275              0.702442
# 30                     17.0          0.817362              0.041404
# 31                     38.0          0.007536              0.091052
# 32                     34.0          0.000001              0.009931
# 33                     45.0          0.248088              0.020285
# 34                      5.0          0.013061              0.024464
# 35                     35.0          0.874775              0.141840
# 36                      6.0          0.618104              0.568660
# 37                      5.0          0.693353              0.064746
#
#      fit_beta  log_likelihood  BIC_model2  likelihood_per_trial  Iteration
# 0    8.455384      -37.290661   88.080751              0.660776          2
# 1    3.667169      -45.570645  104.640718              0.602697          1
# 2    1.000000      -62.383247  138.265956              0.500000          4
# 3   50.000000      -43.137842   99.775113              0.619211          5
# 4   50.000000      -51.243911  115.143905              0.565878          3
# 5   30.445991      -30.236947   73.973323              0.714647          5
# 6   50.000000      -35.157606   83.814641              0.676624          2
# 7    5.964876      -42.036563   97.572554              0.626834          3
# 8    2.204035      -56.309741  126.118910              0.534906          5
# 9   35.726461      -34.947147   83.393724              0.678208          5
# 10   1.896374      -57.735371  129.722724              0.526500          3
# 11  23.012371      -42.283869   98.067150              0.625114          5
# 12  47.093870      -40.666724   94.832877              0.636448          2
# 13   2.873700      -43.615784  104.032958              0.615931          1
# 14  50.000000      -41.303435   96.106299              0.631961          4
# 15   2.682133      -52.638005  118.775439              0.557180          3
# 16  50.000000      -61.240664  135.980757              0.506388          1
# 17   1.000000      -61.781196  137.905829              0.503356          4
# 18  50.000000      -43.643357  100.786143              0.615743          3
# 19   3.662884      -40.617751   94.734930              0.636794          1
# 20   2.074734      -54.871287  124.475496              0.543524          3
# 21  50.000000      -44.823605  103.146639              0.607721          5
# 22  11.346782      -61.584470  136.679675              0.504457          3
# 23   1.000000      -62.252242  138.010401              0.500728          3
# 24   1.000000      -62.383256  138.265989              0.500000          4
# 25   4.044741      -62.383266  138.266222              0.500000          2
# 26  50.000000      -41.703109   96.906031              0.629161          2
# 27   1.000000      -61.670599  136.974684              0.503975          2
# 28  33.152733      -60.548016  136.052595              0.510300          1
# 29   4.288695      -37.286950  125.850391              0.660803          4
# 30  21.053514      -35.715326   84.930082              0.672444          1
# 31   8.359299      -54.949897  123.968847              0.543050          4
# 32  50.000000      -58.163786  129.827000              0.524000          2
# 33   8.539725      -46.493421  106.871554              0.596549          2
# 34  21.329646      -47.031712  107.562853              0.592992          2
# 35  10.046469      -35.796153   85.091736              0.671840          2
# 36   4.053596      -37.893561   89.286550              0.656364          3
# 37   7.692783      -43.016337   99.532102              0.620047          1

# %%
### All subjects 
df_highest_likelihood.to_csv('../../3_results/model_2/N76_parameters.csv')

# %%
### HC
df_highest_likelihood.to_csv('../../3_results/model_2/HC_parameters.csv')

# %%
### MDD

df_highest_likelihood.to_csv('../../3_results/model_2/MDD_parameters.csv')

# %% [markdown]
# ### Extract RPEs

# %%
os.getcwd()
# Out:
# '/Users/jackiebeltran/Documents/GitHub/RP_Learning/1_scripts/model_2'

# %%
def likelihood_mle_outputs(r_alpha, p_alpha, actions, rewards, condition):
        
    q_value = np.ones((3,2))*0.0
    T = len(actions)
    L = 0  
    RPE = []
    
    for t in range(T): # for every trial 
        
        # compute choice probabilities of picking an action based on soft max 
        # p = np.exp(beta * q_value[condition[t]-1,:]) / (np.exp(beta * q_value[condition[t]-1,:])).sum()

        # # compute choice probability for actual choice based on the probability computed above by condition 
        # choiceProb = p[actions[t]-1]

        # # sum of the natural log of each individual choice probability to get the prob of a whole dataset (90 trials)
        # L += np.log(choiceProb) 

        # update values with q learning, index for t and update by condition 
        if condition[t] == 1:
            rpe_r = rewards[t] - q_value[condition[t]-1, actions[t]-1]     
            q_value[condition[t]-1, actions[t]-1] = q_value[condition[t]-1, actions[t]-1] + r_alpha * (rpe_r)
            RPE.append(rpe_r)
            
        elif condition[t] == 2:
            rpe_p = rewards[t] - q_value[condition[t]-1, actions[t]-1]
            q_value[condition[t]-1, actions[t]-1] = q_value[condition[t]-1, actions[t]-1] + p_alpha * (rpe_p)
            RPE.append(rpe_p)
            
        elif condition[t] == 3: 
            rpe_n = 0 
            RPE.append(rpe_n)
        
    return RPE

# %%
def lat_vars(filename):
    
    a = os.path.basename(filename)
    subID = os.path.splitext(a)[0]

    # load data & subset for columns of interest
    sub_df = pd.read_csv(filename)

    # Obtain vars of interest (actions, rewards, conditions)  
    condition = sub_df["condition"]
    actions = sub_df['actions']
    rewards = sub_df['rewards']
    
    r_alpha = sub_df['fit_reward_alpha'].iloc[0]
    
    p_alpha = sub_df['fit_punishment_alpha'].iloc[0]
    
    #fit_beta = sub_df['fit_beta'].iloc[0]
       
    # extract RPEs
    rpes = likelihood_mle_outputs(r_alpha, p_alpha, actions, rewards, condition)
    
    results_df = pd.DataFrame(rpes, columns = ['RPE'])
    results_df['sub_ID'] = subID
    results_df = results_df[['sub_ID', 'RPE']]
    
    results_df.to_csv(f'../../3_results/model_2/RPEs/{subID}_RPE.csv')

# %% [markdown]
# ##### load data

# %%
### Healthy Controls 
df1_files = glob.glob('../../0_data/healthy/*.csv') 
df_highest_likelihood = pd.read_csv(f'/Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/HC_parameters.csv')

# %%
### MDD 
df1_files = glob.glob('../../0_data/mdd/*.csv') 
df_highest_likelihood = pd.read_csv(f'/Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/MDD_parameters.csv')

# %%
df_highest_likelihood.head(5)
# Out:
#    Unnamed: 0  subject_ID  initial_reward_conditions  \
# 0           0         501                   0.613797
# 1           1         502                   0.208690
# 2           2         503                   0.521664
# 3           3         504                   0.192704
# 4           4         506                   0.513802
#
#    initial_punishment_conditions  initial_beta_conditions  fit_reward_alpha  \
# 0                       0.668543                      4.0          0.646656
# 1                       0.986033                     15.0          1.000000
# 2                       0.093482                     11.0          0.340769
# 3                       0.565117                     19.0          0.109320
# 4                       0.488712                     47.0          0.121509
#
#    fit_punishment_alpha   fit_beta  log_likelihood  BIC_model2  \
# 0              0.119117   6.709861      -41.818905   98.214834
# 1              0.783051   3.021224      -48.528095  114.427152
# 2              0.015024  50.000000      -37.243030   87.985488
# 3              1.000000   5.650866      -37.352489   88.204406
# 4              0.323182   6.670178      -34.830305   83.160039
#
#    likelihood_per_trial  Iteration
# 0              0.628352          5
# 1              0.583214          5
# 2              0.661126          5
# 3              0.660322          4
# 4              0.679089          3

# %%
# empty list to create a single dataframe with all subjects behavioral data
df1_dataframes = []

# load and append each df1 dataframe to the list
for file in df1_files:
    
    df = pd.read_csv(file)
    
    col_name = ['sub_ID', 'actions','rewards', 'condition']   
    df = df[col_name]    
    
    df1_dataframes.append(df)

combined_df = pd.concat(df1_dataframes, ignore_index=True)

# %%
combined_df.head(10)
# Out:
#    sub_ID  actions  rewards  condition
# 0     545        1        1          1
# 1     545        2        0          3
# 2     545        1        0          2
# 3     545        1        0          3
# 4     545        2       -1          2
# 5     545        1        1          1
# 6     545        1        1          1
# 7     545        1        1          1
# 8     545        1        1          1
# 9     545        1        0          2

# %%
# load parameters with greatest likelihood

cols = ['sub_ID', 'fit_reward_alpha', 'fit_punishment_alpha', 'fit_beta']
df_highest_likelihood.rename(columns = {'subject_ID':'sub_ID'}, inplace = True)

df_highest_likelihood = df_highest_likelihood[cols]

# %%
df_highest_likelihood.head(5)

# subset df_highest_likelihood dataframe for a specific sub_ID
df_highest_likelihood.loc[df_highest_likelihood['sub_ID'] == 545]
# Out:
#     sub_ID  fit_reward_alpha  fit_punishment_alpha  fit_beta
# 33     545          0.318487              0.444252   2.80489

# %%
# create one dataframe with behavioral data & parameters for each subject

params_df = pd.merge(combined_df, df_highest_likelihood)
params_df
# Out:
#       sub_ID  actions  rewards  condition  fit_reward_alpha  \
# 0        545        1        1          1          0.318487
# 1        545        2        0          3          0.318487
# 2        545        1        0          2          0.318487
# 3        545        1        0          3          0.318487
# 4        545        2       -1          2          0.318487
# ...      ...      ...      ...        ...               ...
# 3415     548        2        0          3          0.000556
# 3416     548        1        1          1          0.000556
# 3417     548        1        0          2          0.000556
# 3418     548        1        1          1          0.000556
# 3419     548        1        0          3          0.000556
#
#       fit_punishment_alpha   fit_beta
# 0                 0.444252   2.804890
# 1                 0.444252   2.804890
# 2                 0.444252   2.804890
# 3                 0.444252   2.804890
# 4                 0.444252   2.804890
# ...                    ...        ...
# 3415              0.032636  11.434186
# 3416              0.032636  11.434186
# 3417              0.032636  11.434186
# 3418              0.032636  11.434186
# 3419              0.032636  11.434186
#
# [3420 rows x 7 columns]

# %%
params_df.loc[params_df['sub_ID'] == 545]
# Out:
#     sub_ID  actions  rewards  condition  fit_reward_alpha  \
# 0      545        1        1          1          0.318487
# 1      545        2        0          3          0.318487
# 2      545        1        0          2          0.318487
# 3      545        1        0          3          0.318487
# 4      545        2       -1          2          0.318487
# ..     ...      ...      ...        ...               ...
# 85     545        1       -1          2          0.318487
# 86     545        1        0          3          0.318487
# 87     545        1        1          1          0.318487
# 88     545        1        0          3          0.318487
# 89     545        1        0          2          0.318487
#
#     fit_punishment_alpha  fit_beta
# 0               0.444252   2.80489
# 1               0.444252   2.80489
# 2               0.444252   2.80489
# 3               0.444252   2.80489
# 4               0.444252   2.80489
# ..                   ...       ...
# 85              0.444252   2.80489
# 86              0.444252   2.80489
# 87              0.444252   2.80489
# 88              0.444252   2.80489
# 89              0.444252   2.80489
#
# [90 rows x 7 columns]

# %%
# save dataframe with participant data & parameters into individual subject dataframes

grouped = params_df.groupby('sub_ID')

output_directory = '/Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params'

for group_name, group_df in grouped:
    file_name = os.path.join(output_directory, f'{group_name}.csv')  # Generate a unique file name for each group
    group_df.to_csv(file_name, index=False)

# %% [markdown]
# ##### extract RPEs

# %%
hlist = glob.glob('/Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/5*.csv')
mlist = glob.glob('/Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/4*.csv')

print(len(hlist))
print(len(mlist))
# Out:
# 38
# 38

# %%
for name in mlist:
# for name in hlist:
    print(name)
    lat_vars(name)
# Out:
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/431.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/425.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/419.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/418.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/424.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/430.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/432.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/427.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/423.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/436.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/422.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/408.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/434.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/420.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/421.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/435.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/409.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/446.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/447.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/453.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/445.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/451.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/450.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/444.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/440.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/454.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/455.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/443.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/442.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/410.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/438.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/413.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/402.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/416.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/417.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/415.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/401.csv
# /Users/jackiebeltran/Documents/GitHub/RP_Learning/3_results/model_2/final_params/428.csv
